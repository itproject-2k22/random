# %%
import random
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
def generateDataRandom():
    data = []
    for i in range(100):
        data.append(random.random())
    return data

def getMean(data):
    sum = 0
    for i in data:
        sum = sum + i
    mean = sum/len(data)
    return mean

def getVariance(data):
    sum = 0
    mean = getMean(data)
    for i in data:
        sum = sum + (i-mean)**2
    variance = sum/len(data)
    return variance

def getStd(data):
    std = getVariance(data)**0.5
    return std 

def getMin(data):
    min = data[0]
    for i in data:
        if min > i:
            min = i
    return min

def getMax(data):
    max = data[0]
    for i in data:
        if max > i:
            max = i
    return max

def getHistogram(data, title='', xlabel='', ylabel=''):
    plt.hist(data, edgecolor='black')
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()
    
def getPlot(data, title='', xlabel='', ylabel=''):
    plt.plot(data)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()

def getBoxplot(data, title='', xlabel='', ylabel=''):
    plt.boxplot(data)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()
    
def normalTestPlot(data, title=''):
    stats.probplot(data, dist='norm', plot=plt)
    plt.title('')
    plt.show

# %%
data = generateDataRandom()
print(data, end='\n')
print("mean\t:", getMean(data))
print("var\t:", getVariance(data))
print("std\t:", getStd(data))
print("min\t:", getMin(data))
print("max\t:", getMax(data))
getHistogram(data)
getPlot(data)
getBoxplot(data)
normalTestPlot(data)
# Out:
# [0.9993190024691283, 0.4517498053899781, 0.9806854566558536, 0.1707762247392749, 0.08817281924688769, 0.12330335603537468, 0.1632009327023537, 0.4506807365966121, 0.49776943563042453, 0.6613351501945354, 0.8088424612132784, 0.6407826092359855, 0.4014544133362401, 0.18359170061560137, 0.277226949894686, 0.6254455716434328, 0.8993814183126315, 0.5094731691097176, 0.9745455562626626, 0.0003290966636793069, 0.1598679582821373, 0.3194433064106508, 0.30147143882439653, 0.2569542523959979, 0.751080327141072, 0.9388688382558081, 0.6112506723918627, 0.06415411667731807, 0.22013635170462997, 0.621965129935289, 0.36156709201968174, 0.5908574806074894, 0.5366553334760022, 0.8121965007045403, 0.34028394338332657, 0.36354874848687435, 0.9929103899852952, 0.27102980957599965, 0.07275758217219386, 0.32514021412367644, 0.4318630130715789, 0.5905838919822076, 0.40939278269347135, 0.4711165070774913, 0.2978887415788849, 0.03380509399824494, 0.4046513382488234, 0.007714965284487785, 0.3414643801885504, 0.5391709908404337, 0.25282351705781814, 0.3422057384500826, 0.9526912044746314, 0.21619591317211162, 0.5580044193949277, 0.8459985498745413, 0.3979918954086029, 0.6941300024815247, 0.8076527083089805, 0.03617701237252302, 0.0559033274088524, 0.42308638449636615, 0.7276446645370576, 0.5235099597087423, 0.6020799835761993, 0.601688600262247, 0.7145587149735118, 0.27432559018369895, 0.1323315391115658, 0.7734197561347749, 0.6738273746947632, 0.28522388230821916, 0.49698644778500434, 0.8251760351016668, 0.5752828503956693, 0.7463178652344717, 0.900392390021058, 0.03871265739002949, 0.14833091062565196, 0.600547761740351, 0.36389787183595756, 0.990900496607072, 0.6756301501523815, 0.11682078855737743, 0.7204309838274823, 0.38044159251566556, 0.2869493207963151, 0.4693246296571758, 0.7297992991771749, 0.30883794202905623, 0.22370507224614133, 0.42180300512541125, 0.3343297232884207, 0.48083394976958616, 0.8713619015196536, 0.4937738958086021, 0.9787537332841579, 0.935740614978592, 0.10076107880444274, 0.8853527406304333]
# mean	: 0.48340523504763505
# var	: 0.07778648991832411
# std	: 0.27890229457342963
# min	: 0.0003290966636793069
# max	: 0.0003290966636793069
