# %%
import random
import matplotlib.pyplot as plt

# %%
def generateDataRandom():
    data = []
    for i in range(100):
        data.append(random.random())
    return data

def getMean(data):
    sum = 0
    for i in data:
        sum = sum + i
    mean = sum/len(data)
    return mean

def getVariance(data):
    sum = 0
    mean = getMean(data)
    for i in data:
        sum = sum + (i-mean)**2
    variance = sum/len(data)
    return variance

def getStd(data):
    std = getVariance(data)**0.5
    return std 

def getMin(data):
    min = data[0]
    for i in data:
        if min > i:
            min = i
    return min

def getMax(data):
    max = data[0]
    for i in data:
        if max > i:
            max = i
    return max

def getHistogram(data, title='', xlabel='', ylabel=''):
    plt.hist(data, edgecolor='black')
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()
    
def getPlot(data, title='', xlabel='', ylabel=''):
    plt.plot(data)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()

def getBoxplot(data, title='', xlabel='', ylabel=''):
    plt.boxplot(data)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()

# %%
data = generateDataRandom()
print(data, end='\n')
print("mean\t:", getMean(data))
print("var\t:", getVariance(data))
print("std\t:", getStd(data))
print("min\t:", getMin(data))
print("max\t:", getMax(data))
getHistogram(data)
getPlot(data)
getBoxplot(data)
# Out:
# [0.9586931557314321, 0.5171146579913198, 0.8214262156282283, 0.026591757213406675, 0.5541064480022572, 0.09977131473812151, 0.5798770422921717, 0.07981847106425288, 0.6797783843349767, 0.19136138000407632, 0.46220394342741644, 0.652168290328194, 0.08004334868235097, 0.8245159578796554, 0.5001823498090997, 0.157347211054366, 0.41469216006460186, 0.44088051229970127, 0.44226907537714133, 0.6046139070717123, 0.1685843643230862, 0.08088479359546541, 0.6773563225895347, 0.9922140872171568, 0.07938924321893259, 0.7962784538216808, 0.7105211595036302, 0.3788249425749858, 0.49810694152448354, 0.6435697844436133, 0.2649516548455473, 0.555471550843485, 0.8825171155901467, 0.7636754684796128, 0.4061707530342812, 0.2527729538299358, 0.32201138741116153, 0.16002648946426523, 0.8013649471280352, 0.7082245604205094, 0.857736445259981, 0.029228514860743737, 0.20157055965835913, 0.855130927953838, 0.27751584585731104, 0.9245799833017992, 0.8291606138396076, 0.814247051271183, 0.3057014564906677, 0.15151179477832188, 0.22826002767948184, 0.2900365583396577, 0.8930860712796009, 0.9666987342148416, 0.9833816296056119, 0.5180677724919546, 0.1515879547522344, 0.3483495975326587, 0.3396993894044802, 0.8398600388910628, 0.9225478569400206, 0.7853384083868585, 0.8989105480088464, 0.8137814652508474, 0.9984829418503692, 0.7447513880111505, 0.8559579925278467, 0.22800149831768202, 0.15520790973521992, 0.5358666627780119, 0.2714949659045601, 0.1957656820764877, 0.6206779510199775, 0.6841311600868949, 0.5064587405240221, 0.9206036458987069, 0.7110318919635241, 0.47201039304405557, 0.5281946701559833, 0.9979466238401371, 0.6550703081312067, 0.45633286377623483, 0.4928450353097331, 0.0055455900098932975, 0.9080858827526689, 0.7591842670638247, 0.03208808697072041, 0.071183275760344, 0.10007149339536348, 0.684371512196805, 0.019051030794702495, 0.09866787160695556, 0.6101658039434414, 0.9922899524352752, 0.15040159961334731, 0.4830678993792833, 0.02117104743778564, 0.8410044373131633, 0.392041861993935, 0.8333681390663206]
# mean	: 0.5148895387958965
# var	: 0.0928776491566002
# std	: 0.3047583455077157
# min	: 0.0055455900098932975
# max	: 0.0055455900098932975

# %%
# Out:
# 0.0
