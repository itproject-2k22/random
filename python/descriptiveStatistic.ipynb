# %%
import random
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
def generateDataRandom():
    data = []
    for i in range(100):
        data.append(random.random())
    return data

def getMean(data):
    sum = 0
    for i in data:
        sum = sum + i
    mean = sum/len(data)
    return mean

def getVariance(data):
    sum = 0
    mean = getMean(data)
    for i in data:
        sum = sum + (i-mean)**2
    variance = sum/len(data)
    return variance

def getStd(data):
    std = getVariance(data)**0.5
    return std 

def getMin(data):
    min = data[0]
    for i in data:
        if min > i:
            min = i
    return min

def getMax(data):
    max = data[0]
    for i in data:
        if max < i:
            max = i
    return max

def getRange(data):
    max = getMax(data)
    min = getMin(data)
    range = max-min
    return range

def getHistogram(data, title='', xlabel='', ylabel=''):
    plt.hist(data, edgecolor='black')
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()
    
def getPlot(data, title='', xlabel='', ylabel=''):
    plt.plot(data)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()

def getBoxplot(data, title='', xlabel='', ylabel=''):
    plt.boxplot(data)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()
    
def normalTestPlot(data, title=''):
    stats.probplot(data, dist='norm', plot='plt')
    plt.title(title)
    plt.show
    
def getScatterPlot(x, y, title='', xlabel='', ylabel=''):
    plt.scatter(x,y)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()

# %%
data = generateDataRandom()
data2 = generateDataRandom()
print(data, end='\n')
print("mean\t:", getMean(data))
print("var\t:", getVariance(data))
print("std\t:", getStd(data))
print("min\t:", getMin(data))
print("max\t:", getMax(data))
print("range\t:", getMax(data))
getHistogram(data)
getPlot(data)
getBoxplot(data)
normalTestPlot(data)
getScatterPlot(data, data2)
# Out:
# [0.028323222154814975, 0.3159304989624865, 0.2132278590940211, 0.46590961589578805, 0.051302771611256515, 0.30461680333233876, 0.6863829670487833, 0.04886029529352853, 0.008308046463062269, 0.8001110459583277, 0.6496206683796707, 0.7107931115275645, 0.7894868168382678, 0.954433333933026, 0.11972761068578042, 0.40813887536679505, 0.6834046999589724, 0.2514419300212303, 0.42712662557182, 0.28279078234368404, 0.4612852795509542, 0.7607634648302997, 0.03201810855115028, 0.0143868599540945, 0.6099948581555094, 0.6063174734577881, 0.23108192163980834, 0.2551219848321089, 0.9694550549382872, 0.08204670665169345, 0.010308349827398477, 0.2970861430754955, 0.8458952204121237, 0.5151328698648425, 0.48102140943009697, 0.5382586855896809, 0.2875895659135156, 0.9916041630991557, 0.7087162126245852, 0.6597712365498023, 0.9857163518635962, 0.06042092580277403, 0.30905381492315487, 0.07204400891414486, 0.7629804438796305, 0.5775082082903619, 0.7396431796397558, 0.04534780730708998, 0.8039912285985948, 0.6512561741167483, 0.044807738667445585, 0.7486787363390321, 0.7238500130471864, 0.44905663763770143, 0.2747907026010471, 0.45282307446489134, 0.4525323405271935, 0.5894550142152513, 0.1473654108279009, 0.8172492678255101, 0.1534765521022905, 0.9888192823533334, 0.7364881239095354, 0.6118235453255956, 0.6611367907023185, 0.7187994328453885, 0.7160240832418289, 0.660710264791758, 0.9828005927742104, 0.0878785393204694, 0.6871599680504038, 0.6198680334271546, 0.945153163723968, 0.5532594199094176, 0.34549632307368083, 0.581719003509745, 0.04994150059822744, 0.7083278122988328, 0.02993101586655167, 0.29727694514929237, 0.8228252422287162, 0.38119086873616925, 0.4478208729532607, 0.028506917944484345, 0.5173743485894337, 0.09801658775637334, 0.6013592273783351, 0.26693753729046554, 0.25685087243094906, 0.2804942877121043, 0.28722468037343096, 0.02884444402261266, 0.109845332358954, 0.009459292427680399, 0.883290364890215, 0.8782336999681766, 0.8911277920874058, 0.23524467137078342, 0.7289187883238172, 0.9055407649418608]
# mean	: 0.47061561215637837
# var	: 0.09100887605563517
# std	: 0.30167677414019656
# min	: 0.008308046463062269
# max	: 0.9916041630991557
# range	: 0.9916041630991557
