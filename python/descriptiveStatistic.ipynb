# %%
import random
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
def generateDataRandom():
    data = []
    for i in range(100):
        data.append(random.random())
    return data

def getMean(data):
    sum = 0
    for i in data:
        sum = sum + i
    mean = sum/len(data)
    return mean

def getVariance(data):
    sum = 0
    mean = getMean(data)
    for i in data:
        sum = sum + (i-mean)**2
    variance = sum/len(data)
    return variance

def getStd(data):
    std = getVariance(data)**0.5
    return std 

def getMin(data):
    min = data[0]
    for i in data:
        if min > i:
            min = i
    return min

def getMax(data):
    max = data[0]
    for i in data:
        if max < i:
            max = i
    return max

def getRange(data):
    max = getMax(data)
    min = getMin(data)
    range = max-min
    return range

def getHistogram(data, title='', xlabel='', ylabel=''):
    plt.hist(data, edgecolor='black')
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()
    
def getPlot(data, title='', xlabel='', ylabel=''):
    plt.plot(data)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()

def getBoxplot(data, title='', xlabel='', ylabel=''):
    plt.boxplot(data)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()
    
def normalTestPlot(data, title=''):
    stats.probplot(data, dist='norm', plot=plt)
    plt.title(title)
    plt.show
    
def getScatterPlot(x, y, title='', xlabel='', ylabel=''):
    plt.scatter(x,y)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()

# %%
data = generateDataRandom()
data2 = generateDataRandom()
print(data, end='\n')
print("mean\t:", getMean(data))
print("var\t:", getVariance(data))
print("std\t:", getStd(data))
print("min\t:", getMin(data))
print("max\t:", getMax(data))
print("range\t:", getMax(data))
getHistogram(data)
getPlot(data)
getBoxplot(data)
normalTestPlot(data)
getScatterPlot(data, data2)
# Out:
# [0.692649267499746, 0.013002077035603188, 0.45490977260246845, 0.04606117274988264, 0.18694305807745526, 0.42164044452128124, 0.9657832819295319, 0.2524628545844052, 0.08077009240722521, 0.06872785650489122, 0.9123172150577424, 0.596971584465918, 0.1151138453045647, 0.8868764126397334, 0.9538274750068445, 0.33333590648176914, 0.4705756405915741, 0.8413295957452441, 0.6239867785794778, 0.978977273090111, 0.9109019156771604, 0.7611483776339191, 0.5423573902323101, 0.6915549063967811, 0.5591281469678926, 0.5147416818655216, 0.03640330667716607, 0.3056208562261009, 0.9780149649317184, 0.04432168716008744, 0.7109382956777849, 0.5418103338213985, 0.4718515151461108, 0.8224717424776848, 0.9099983022767129, 0.5196591761674386, 0.06940659847638508, 0.34138593167798914, 0.7282634025765353, 0.6244074619476023, 0.444992917410871, 0.6471663304456694, 0.22875411113108768, 0.6248124260584893, 0.6650298688240628, 0.9941722274426152, 0.5103415746839912, 0.3338265232722173, 0.38964084834433466, 0.7602918552508985, 0.9217273531155233, 0.675306774030172, 0.9012277348097056, 0.5650860058377178, 0.42427903454115845, 0.8995292318348904, 0.7837249978845612, 0.2885590836218124, 0.9701276109009548, 0.5326873207133583, 0.6677375572417431, 0.8548479444786025, 0.5588499275392648, 0.7045181306067112, 0.8132934779452548, 0.12305498179048169, 0.552307774861509, 0.8906622389028342, 0.06310018940324813, 0.8339048915659548, 0.3335178118574118, 0.6641415719408489, 0.7815811177176377, 0.18415139640644151, 0.06119887324321316, 0.5619572724102154, 0.6241841199187128, 0.4892154480467831, 0.5005803874631416, 0.1508503895518245, 0.5327407761692261, 0.23620397403465965, 0.5043024140285302, 0.9185285177005229, 0.7482591932155729, 0.4646755203432015, 0.7155753976152569, 0.4993860106446927, 0.46356844730375013, 0.3826278456739175, 0.8863792970458192, 0.7133722149250687, 0.30597930547488916, 0.7793007346220692, 0.013268871833274742, 0.7725448747029208, 0.860069836497338, 0.33139607649068303, 0.02857280538454332, 0.3463401636279658]
# mean	: 0.5445867920926959
# var	: 0.07906690803200489
# std	: 0.28118838530779483
# min	: 0.013002077035603188
# max	: 0.9941722274426152
# range	: 0.9941722274426152
